# %%
import cv2 
import matplotlib.pyplot as plt

img = cv2.imread("../../images/task_3_and_4/" + 'left' + "_0.png")
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
backtobgr = cv2.cvtColor(gray,cv2.COLOR_GRAY2RGB)

plt.imshow(img)
